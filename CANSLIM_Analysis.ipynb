# %% [markdown]
# <a href="https://colab.research.google.com/github/crowsol/CANSLIM/blob/feature%2FFidelity/CANSLIM_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# CANSLIM Stock Analysis System
# A comprehensive implementation of William O'Neil's CANSLIM methodology

# Install required packages
# !pip install yfinance pandas numpy matplotlib seaborn plotly requests beautifulsoup4 ta-lib

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import requests
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# Set up plotting style
plt.style.use('seaborn-v0_8')
sns.set_palette("husl")

class CANSLIMAnalyzer:
    def __init__(self, symbol, period='2y'):
        """
        Initialize CANSLIM analyzer for a given stock symbol

        Parameters:
        symbol (str): Stock ticker symbol
        period (str): Time period for analysis ('1y', '2y', '5y', etc.)
        """
        self.symbol = symbol.upper()
        self.period = period
        self.stock = yf.Ticker(self.symbol)

        # Fetch data
        self.data = self.stock.history(period=period)
        self.info = self.stock.info
        self.financials = self.stock.financials
        self.quarterly_financials = self.stock.quarterly_financials

        # CANSLIM scores
        self.canslim_scores = {}

    def analyze_current_earnings(self):
        """
        C - Current Quarterly Earnings
        Look for 25%+ earnings growth in recent quarters
        """
        try:
            # Get quarterly earnings data
            quarterly_earnings = self.stock.quarterly_earnings

            if quarterly_earnings is None or quarterly_earnings.empty:
                return 0, "No quarterly earnings data available"

            # Calculate earnings growth rates
            earnings_growth = []
            for i in range(1, min(5, len(quarterly_earnings))):
                current = quarterly_earnings.iloc[i-1]['Earnings']
                previous = quarterly_earnings.iloc[i]['Earnings']

                if previous != 0:
                    growth = ((current - previous) / abs(previous)) * 100
                    earnings_growth.append(growth)

            if not earnings_growth:
                return 0, "Insufficient earnings data for growth calculation"

            # Score based on recent earnings growth
            recent_growth = np.mean(earnings_growth[:2])  # Last 2 quarters

            if recent_growth >= 25:
                score = 100
            elif recent_growth >= 15:
                score = 80
            elif recent_growth >= 10:
                score = 60
            elif recent_growth >= 5:
                score = 40
            elif recent_growth >= 0:
                score = 20
            else:
                score = 0

            analysis = f"Recent earnings growth: {recent_growth:.1f}%"
            return score, analysis

        except Exception as e:
            return 0, f"Error analyzing current earnings: {str(e)}"

    def analyze_annual_earnings(self):
        """
        A - Annual Earnings Growth
        Look for 25%+ annual earnings growth over 3-5 years
        """
        try:
            # Get annual earnings data
            if self.financials is None or self.financials.empty:
                return 0, "No annual financial data available"

            # Get net income (earnings) data
            if 'Net Income' not in self.financials.index:
                return 0, "Net income data not available"

            net_income = self.financials.loc['Net Income'].dropna()

            if len(net_income) < 2:
                return 0, "Insufficient annual earnings data"

            # Calculate year-over-year growth rates
            growth_rates = []
            for i in range(1, len(net_income)):
                current = net_income.iloc[i-1]
                previous = net_income.iloc[i]

                if previous != 0:
                    growth = ((current - previous) / abs(previous)) * 100
                    growth_rates.append(growth)

            if not growth_rates:
                return 0, "Cannot calculate annual growth rates"

            # Score based on average annual growth
            avg_growth = np.mean(growth_rates)

            if avg_growth >= 25:
                score = 100
            elif avg_growth >= 20:
                score = 80
            elif avg_growth >= 15:
                score = 60
            elif avg_growth >= 10:
                score = 40
            elif avg_growth >= 0:
                score = 20
            else:
                score = 0

            analysis = f"Average annual earnings growth: {avg_growth:.1f}%"
            return score, analysis

        except Exception as e:
            return 0, f"Error analyzing annual earnings: {str(e)}"

    def analyze_new_products(self):
        """
        N - New Products, Services, or Management
        This is harder to quantify, so we'll use revenue growth as a proxy
        """
        try:
            if 'Total Revenue' not in self.financials.index:
                return 50, "Revenue data not available - using neutral score"

            revenue = self.financials.loc['Total Revenue'].dropna()

            if len(revenue) < 2:
                return 50, "Insufficient revenue data"

            # Calculate revenue growth
            recent_revenue = revenue.iloc[0]
            previous_revenue = revenue.iloc[1]

            if previous_revenue != 0:
                revenue_growth = ((recent_revenue - previous_revenue) / abs(previous_revenue)) * 100
            else:
                return 50, "Cannot calculate revenue growth"

            # Score based on revenue growth (proxy for new products/services)
            if revenue_growth >= 20:
                score = 100
            elif revenue_growth >= 15:
                score = 80
            elif revenue_growth >= 10:
                score = 60
            elif revenue_growth >= 5:
                score = 40
            elif revenue_growth >= 0:
                score = 20
            else:
                score = 0

            analysis = f"Revenue growth: {revenue_growth:.1f}% (proxy for new products/services)"
            return score, analysis

        except Exception as e:
            return 50, f"Error analyzing new products: {str(e)}"

    def analyze_supply_demand(self):
        """
        S - Supply and Demand (Volume Analysis)
        Look for increasing volume on up days and decreasing volume on down days
        """
        try:
            # Calculate price changes and volume patterns
            self.data['Price_Change'] = self.data['Close'].pct_change()
            self.data['Volume_MA'] = self.data['Volume'].rolling(window=20).mean()
            self.data['Volume_Ratio'] = self.data['Volume'] / self.data['Volume_MA']

            # Analyze recent volume patterns (last 20 days)
            recent_data = self.data.tail(20)

            up_days = recent_data[recent_data['Price_Change'] > 0]
            down_days = recent_data[recent_data['Price_Change'] < 0]

            if len(up_days) > 0 and len(down_days) > 0:
                avg_volume_up = up_days['Volume_Ratio'].mean()
                avg_volume_down = down_days['Volume_Ratio'].mean()

                volume_pattern = avg_volume_up - avg_volume_down

                if volume_pattern > 0.3:
                    score = 100
                elif volume_pattern > 0.1:
                    score = 80
                elif volume_pattern > 0:
                    score = 60
                elif volume_pattern > -0.1:
                    score = 40
                else:
                    score = 20

                analysis = f"Volume pattern score: {volume_pattern:.2f} (higher volume on up days is positive)"
            else:
                score = 50
                analysis = "Insufficient price movement data for volume analysis"

            return score, analysis

        except Exception as e:
            return 50, f"Error analyzing supply and demand: {str(e)}"

    def analyze_leader_laggard(self):
        """
        L - Leader or Laggard
        Compare stock performance to market (S&P 500)
        """
        try:
            # Get S&P 500 data for comparison
            spy = yf.download('^GSPC', period=self.period)['Close']

            # Calculate relative performance
            stock_return = (self.data['Close'].iloc[-1] / self.data['Close'].iloc[0] - 1) * 100
            market_return = (spy.iloc[-1] / spy.iloc[0] - 1) * 100

            relative_performance = stock_return - market_return

            # Score based on relative performance
            if relative_performance > 20:
                score = 100
            elif relative_performance > 10:
                score = 80
            elif relative_performance > 0:
                score = 60
            elif relative_performance > -10:
                score = 40
            elif relative_performance > -20:
                score = 20
            else:
                score = 0

            analysis = f"Stock return: {stock_return:.1f}%, Market return: {market_return:.1f}%, Relative: {relative_performance:.1f}%"
            return score, analysis

        except Exception as e:
            return 50, f"Error analyzing leader/laggard: {str(e)}"

    def analyze_institutional_sponsorship(self):
        """
        I - Institutional Sponsorship
        Use trading volume as a proxy for institutional interest
        """
        try:
            # Calculate average volume metrics
            avg_volume = self.data['Volume'].mean()
            recent_volume = self.data['Volume'].tail(20).mean()

            # Get market cap for context
            market_cap = self.info.get('marketCap', 0)

            # Score based on volume and market cap (proxies for institutional interest)
            volume_increase = (recent_volume / avg_volume - 1) * 100

            if market_cap > 10e9 and volume_increase > 20:  # Large cap with volume increase
                score = 100
            elif market_cap > 2e9 and volume_increase > 10:  # Mid cap with volume increase
                score = 80
            elif market_cap > 500e6 and volume_increase > 0:  # Small cap with volume increase
                score = 60
            elif market_cap > 100e6:  # Micro cap
                score = 40
            else:
                score = 20

            analysis = f"Market cap: ${market_cap/1e9:.1f}B, Volume change: {volume_increase:.1f}%"
            return score, analysis

        except Exception as e:
            return 50, f"Error analyzing institutional sponsorship: {str(e)}"

    def analyze_market_direction(self):
        """
        M - Market Direction
        Analyze overall market trend using S&P 500
        """
        try:
            # Get S&P 500 data
            spy = yf.download('^GSPC', period='6mo')['Close']

            # Calculate moving averages
            spy_ma20 = spy.rolling(window=20).mean()
            spy_ma50 = spy.rolling(window=50).mean()

            current_price = spy.iloc[-1]
            ma20 = spy_ma20.iloc[-1]
            ma50 = spy_ma50.iloc[-1]

            # Score based on market trend
            if current_price > ma20 > ma50:
                score = 100
                trend = "Strong uptrend"
            elif current_price > ma20:
                score = 80
                trend = "Uptrend"
            elif current_price > ma50:
                score = 60
                trend = "Neutral to positive"
            elif current_price < ma20 < ma50:
                score = 20
                trend = "Downtrend"
            else:
                score = 40
                trend = "Mixed signals"

            analysis = f"Market trend: {trend}"
            return score, analysis

        except Exception as e:
            return 50, f"Error analyzing market direction: {str(e)}"

    def calculate_canslim_score(self):
        """
        Calculate overall CANSLIM score and individual component scores
        """
        print(f"Analyzing {self.symbol} using CANSLIM methodology...")
        print("=" * 50)

        # Analyze each component
        c_score, c_analysis = self.analyze_current_earnings()
        a_score, a_analysis = self.analyze_annual_earnings()
        n_score, n_analysis = self.analyze_new_products()
        s_score, s_analysis = self.analyze_supply_demand()
        l_score, l_analysis = self.analyze_leader_laggard()
        i_score, i_analysis = self.analyze_institutional_sponsorship()
        m_score, m_analysis = self.analyze_market_direction()

        # Store scores
        self.canslim_scores = {
            'Current Earnings (C)': c_score,
            'Annual Earnings (A)': a_score,
            'New Products (N)': n_score,
            'Supply & Demand (S)': s_score,
            'Leader/Laggard (L)': l_score,
            'Institutional (I)': i_score,
            'Market Direction (M)': m_score
        }

        # Calculate overall score
        overall_score = np.mean(list(self.canslim_scores.values()))

        # Print results
        print(f"C - Current Earnings: {c_score}/100 - {c_analysis}")
        print(f"A - Annual Earnings: {a_score}/100 - {a_analysis}")
        print(f"N - New Products: {n_score}/100 - {n_analysis}")
        print(f"S - Supply & Demand: {s_score}/100 - {s_analysis}")
        print(f"L - Leader/Laggard: {l_score}/100 - {l_analysis}")
        print(f"I - Institutional: {i_score}/100 - {i_analysis}")
        print(f"M - Market Direction: {m_score}/100 - {m_analysis}")
        print("=" * 50)
        print(f"Overall CANSLIM Score: {overall_score:.1f}/100")

        return overall_score

    def generate_signals(self):
        """
        Generate buy/sell signals based on CANSLIM analysis
        """
        overall_score = self.calculate_canslim_score()

        # Technical indicators for timing
        self.data['SMA_20'] = self.data['Close'].rolling(window=20).mean()
        self.data['SMA_50'] = self.data['Close'].rolling(window=50).mean()

        current_price = self.data['Close'].iloc[-1]
        sma_20 = self.data['SMA_20'].iloc[-1]
        sma_50 = self.data['SMA_50'].iloc[-1]

        # Generate signals
        if overall_score >= 70 and current_price > sma_20 > sma_50:
            signal = "STRONG BUY"
            color = "green"
        elif overall_score >= 60 and current_price > sma_20:
            signal = "BUY"
            color = "lightgreen"
        elif overall_score >= 40 and current_price > sma_50:
            signal = "HOLD"
            color = "yellow"
        elif overall_score < 40 and current_price < sma_20:
            signal = "SELL"
            color = "orange"
        else:
            signal = "STRONG SELL"
            color = "red"

        print(f"\n🎯 SIGNAL: {signal}")
        print(f"Current Price: ${current_price:.2f}")
        print(f"20-day SMA: ${sma_20:.2f}")
        print(f"50-day SMA: ${sma_50:.2f}")

        return signal, overall_score

    def plot_analysis(self):
        """
        Create comprehensive visualization of the analysis
        """
        fig = make_subplots(
            rows=3, cols=2,
            subplot_titles=('Price Chart with Moving Averages', 'CANSLIM Component Scores',
                          'Volume Analysis', 'Price vs Volume',
                          'Relative Performance vs S&P 500', 'Technical Indicators'),
            specs=[[{"secondary_y": True}, {"type": "bar"}],
                   [{"secondary_y": True}, {"secondary_y": True}],
                   [{"secondary_y": False}, {"secondary_y": False}]]
        )

        # Price chart with moving averages
        fig.add_trace(
            go.Scatter(x=self.data.index, y=self.data['Close'], name='Close Price'),
            row=1, col=1
        )
        fig.add_trace(
            go.Scatter(x=self.data.index, y=self.data['SMA_20'], name='20-day SMA'),
            row=1, col=1
        )
        fig.add_trace(
            go.Scatter(x=self.data.index, y=self.data['SMA_50'], name='50-day SMA'),
            row=1, col=1
        )

        # CANSLIM component scores
        components = list(self.canslim_scores.keys())
        scores = list(self.canslim_scores.values())

        fig.add_trace(
            go.Bar(x=components, y=scores, name='CANSLIM Scores'),
            row=1, col=2
        )

        # Volume analysis
        fig.add_trace(
            go.Scatter(x=self.data.index, y=self.data['Volume'], name='Volume'),
            row=2, col=1
        )
        fig.add_trace(
            go.Scatter(x=self.data.index, y=self.data['Volume_MA'], name='Volume MA'),
            row=2, col=1, secondary_y=True
        )

        # Price vs Volume scatter
        fig.add_trace(
            go.Scatter(x=self.data['Volume'], y=self.data['Close'],
                      mode='markers', name='Price vs Volume'),
            row=2, col=2
        )

        # Relative performance (simplified)
        returns = self.data['Close'].pct_change().cumsum() * 100
        fig.add_trace(
            go.Scatter(x=self.data.index, y=returns, name='Cumulative Returns'),
            row=3, col=1
        )

        # Technical indicators summary
        recent_data = self.data.tail(20)
        fig.add_trace(
            go.Scatter(x=recent_data.index, y=recent_data['Close'],
                      name='Recent Price Action'),
            row=3, col=2
        )

        fig.update_layout(height=1000, showlegend=True,
                         title_text=f"CANSLIM Analysis for {self.symbol}")
        fig.show()

        # CANSLIM scores bar chart
        plt.figure(figsize=(12, 6))
        bars = plt.bar(components, scores, color=['red' if s < 50 else 'yellow' if s < 70 else 'green' for s in scores])
        plt.title(f'CANSLIM Component Scores for {self.symbol}')
        plt.ylabel('Score (0-100)')
        plt.xticks(rotation=45)
        plt.axhline(y=70, color='green', linestyle='--', alpha=0.7, label='Strong Buy Threshold')
        plt.axhline(y=50, color='orange', linestyle='--', alpha=0.7, label='Neutral Threshold')
        plt.legend()
        plt.tight_layout()
        plt.show()

# Example usage and analysis
def analyze_multiple_stocks(symbols, period='1y'):
    """
    Analyze multiple stocks using CANSLIM methodology
    """
    results = {}

    for symbol in symbols:
        print(f"\n{'='*60}")
        print(f"ANALYZING {symbol}")
        print(f"{'='*60}")

        try:
            analyzer = CANSLIMAnalyzer(symbol, period)
            signal, score = analyzer.generate_signals()
            results[symbol] = {
                'signal': signal,
                'score': score,
                'analyzer': analyzer
            }

            # Create visualization
            analyzer.plot_analysis()

        except Exception as e:
            print(f"Error analyzing {symbol}: {str(e)}")
            results[symbol] = {
                'signal': 'ERROR',
                'score': 0,
                'analyzer': None
            }

    return results

# Run analysis on sample stocks
# sample_stocks = ['OUST', 'APP', 'NVAX', 'OLO', 'NVDA', 'USFD', 'CRS', 'PFGC', 'CLS', 'EVLV']
sample_stocks = ['NVDA','TOST','NVAX','OLO','EVLV','XERS','LIF','ISSC','MPWR','PLMR']
# sample_stocks = ['CRS','RYAAY','LMT','RTX','NOC','GD','TOST','FIVE']
print("🚀 Starting CANSLIM Analysis on Sample Stocks")
print("This may take a few minutes to fetch and analyze data...")

results = analyze_multiple_stocks(sample_stocks, period='2y')

# Summary of results
print("\n" + "="*80)
print("CANSLIM ANALYSIS SUMMARY")
print("="*80)

summary_df = pd.DataFrame({
    'Stock': list(results.keys()),
    'Signal': [r['signal'] for r in results.values()],
    'Score': [r['score'] for r in results.values()]
})

summary_df = summary_df.sort_values('Score', ascending=False)
print(summary_df.to_string(index=False))

# Create summary visualization
plt.figure(figsize=(10, 6))
colors = ['red' if s == 'STRONG SELL' or s == 'SELL' else
          'orange' if s == 'HOLD' else
          'lightgreen' if s == 'BUY' else 'green'
          for s in summary_df['Signal']]

bars = plt.bar(summary_df['Stock'], summary_df['Score'], color=colors)
plt.title('CANSLIM Scores Summary')
plt.ylabel('Overall Score (0-100)')
plt.axhline(y=70, color='green', linestyle='--', alpha=0.7, label='Strong Buy Threshold')
plt.axhline(y=60, color='lightgreen', linestyle='--', alpha=0.7, label='Buy Threshold')
plt.axhline(y=40, color='orange', linestyle='--', alpha=0.7, label='Hold/Sell Threshold')
plt.legend()
plt.tight_layout()
plt.show()

# Instructions for custom analysis
print("\n" + "="*80)
print("CUSTOM ANALYSIS INSTRUCTIONS")
print("="*80)
print("To analyze your own stocks, use the following code:")
print()
print("# Single stock analysis")
print("analyzer = CANSLIMAnalyzer('YOUR_SYMBOL', period='2y')")
print("signal, score = analyzer.generate_signals()")
print("analyzer.plot_analysis()")
print()
print("# Multiple stocks analysis")
print("my_stocks = ['STOCK1', 'STOCK2', 'STOCK3']")
print("my_results = analyze_multiple_stocks(my_stocks, period='2y')")
print()
print("Remember:")
print("- CANSLIM is a growth stock methodology")
print("- Scores above 70 indicate strong buy candidates")
print("- Scores below 40 suggest avoiding the stock")
print("- Always consider overall market conditions")
print("- This is for educational purposes - do your own research!")
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.11/dist-packages (0.2.65)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (0.13.2)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (5.24.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (2.32.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (4.13.4)
# Collecting ta-lib
#   Using cached ta_lib-0.6.4.tar.gz (381 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.0.11)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (4.3.8)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.11/dist-packages (from yfinance) (2.4.6)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.11/dist-packages (from yfinance) (3.18.2)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.11/dist-packages (from yfinance) (0.12.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.11/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly) (8.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests) (2025.7.14)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4) (4.14.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from ta-lib) (75.2.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.22)
# Building wheels for collected packages: ta-lib
#   error: subprocess-exited-with-error
#
#   × Building wheel for ta-lib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for ta-lib (pyproject.toml) ... error
#   ERROR: Failed building wheel for ta-lib
# Failed to build ta-lib
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (ta-lib)
# 🚀 Starting CANSLIM Analysis on Sample Stocks
# This may take a few minutes to fetch and analyze data...
#
# ============================================================
# ANALYZING NVDA
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing NVDA using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 100/100 - Average annual earnings growth: 223.7%
# N - New Products: 100/100 - Revenue growth: 114.2% (proxy for new products/services)
# S - Supply & Demand: 80/100 - Volume pattern score: 0.14 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 40/100 - Market cap: $4073.5B, Volume change: -50.1%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 60.0/100
#
# 🎯 SIGNAL: BUY
# Current Price: $167.03
# 20-day SMA: $162.15
# 50-day SMA: $147.39
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c07b71ec-8a67-4797-99ae-c5aa29c4c6b8" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c07b71ec-8a67-4797-99ae-c5aa29c4c6b8")) {                    Plotly.newPlot(                        "c07b71ec-8a67-4797-99ae-c5aa29c4c6b8",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ============================================================
# ANALYZING TOST
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing TOST using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 100/100 - Average annual earnings growth: 53.9%
# N - New Products: 100/100 - Revenue growth: 28.3% (proxy for new products/services)
# S - Supply & Demand: 40/100 - Volume pattern score: -0.01 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 80/100 - Market cap: $27.6B, Volume change: 12.4%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 60.0/100
#
# 🎯 SIGNAL: BUY
# Current Price: $47.65
# 20-day SMA: $44.44
# 50-day SMA: $43.57
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c0c141b0-d18e-4362-a057-0857049f170a" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c0c141b0-d18e-4362-a057-0857049f170a")) {                    Plotly.newPlot(                        "c0c141b0-d18e-4362-a057-0857049f170a",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ============================================================
# ANALYZING NVAX
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing NVAX using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 100/100 - Average annual earnings growth: 48.3%
# N - New Products: 100/100 - Revenue growth: 22.6% (proxy for new products/services)
# S - Supply & Demand: 60/100 - Volume pattern score: 0.10 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 40/100 - Market cap: $1.2B, Volume change: -47.2%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 57.1/100
#
# 🎯 SIGNAL: HOLD
# Current Price: $7.22
# 20-day SMA: $6.81
# 50-day SMA: $6.88
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="57028b6e-5604-4046-8ffb-4f6c6a132b3f" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("57028b6e-5604-4046-8ffb-4f6c6a132b3f")) {                    Plotly.newPlot(                        "57028b6e-5604-4046-8ffb-4f6c6a132b3f",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ============================================================
# ANALYZING OLO
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing OLO using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 80/100 - Average annual earnings growth: 21.0%
# N - New Products: 100/100 - Revenue growth: 24.8% (proxy for new products/services)
# S - Supply & Demand: 100/100 - Volume pattern score: 1.21 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 60/100 - Market cap: $1.7B, Volume change: 290.6%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 62.9/100
#
# 🎯 SIGNAL: BUY
# Current Price: $10.13
# 20-day SMA: $9.65
# 50-day SMA: $9.15
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3fcf0d69-07bd-4632-b755-470028919c8a" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3fcf0d69-07bd-4632-b755-470028919c8a")) {                    Plotly.newPlot(                        "3fcf0d69-07bd-4632-b755-470028919c8a",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ============================================================
# ANALYZING EVLV
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Analyzing EVLV using CANSLIM methodology...
# ==================================================
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 0/100 - Average annual earnings growth: -223.9%
# N - New Products: 100/100 - Revenue growth: 30.5% (proxy for new products/services)
# S - Supply & Demand: 80/100 - Volume pattern score: 0.30 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 60/100 - Market cap: $1.1B, Volume change: 46.9%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 48.6/100
# 🎯 SIGNAL: HOLD
# Current Price: $6.43
# 20-day SMA: $5.94
# 50-day SMA: $5.58
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fced462f-bd79-4c80-abe1-dd759ddd255c" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fced462f-bd79-4c80-abe1-dd759ddd255c")) {                    Plotly.newPlot(                        "fced462f-bd79-4c80-abe1-dd759ddd255c",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ============================================================
# ANALYZING XERS
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing XERS using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 80/100 - Average annual earnings growth: 23.0%
# N - New Products: 100/100 - Revenue growth: 23.9% (proxy for new products/services)
# S - Supply & Demand: 40/100 - Volume pattern score: -0.07 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 60/100 - Market cap: $0.8B, Volume change: 13.4%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 54.3/100
#
# 🎯 SIGNAL: HOLD
# Current Price: $5.12
# 20-day SMA: $4.97
# 50-day SMA: $4.82
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6f6cc5ff-5041-426f-9b5b-b2429dd66005" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f6cc5ff-5041-426f-9b5b-b2429dd66005")) {                    Plotly.newPlot(                        "6f6cc5ff-5041-426f-9b5b-b2429dd66005",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ============================================================
# ANALYZING LIF
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing LIF using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 0/100 - Average annual earnings growth: -6.7%
# N - New Products: 100/100 - Revenue growth: 22.0% (proxy for new products/services)
# S - Supply & Demand: 80/100 - Volume pattern score: 0.13 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 80/100 - Market cap: $5.7B, Volume change: 62.8%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 51.4/100
#
# 🎯 SIGNAL: HOLD
# Current Price: $74.01
# 20-day SMA: $66.43
# 50-day SMA: $63.18
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="386d8cfd-23a9-4af8-a533-d1830be5a764" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("386d8cfd-23a9-4af8-a533-d1830be5a764")) {                    Plotly.newPlot(                        "386d8cfd-23a9-4af8-a533-d1830be5a764",                        [{"name":"Close Price","x":["2024-06-06T00:00:00-04:00","2024-06-07T00:00:00-04:00","2024-06-10T00:00:00-04:00","2024-06-11T00:00:00-04:00","2024-06-12T00:00:00-04:00","2024-06-13T00:00:00-04:00","2024-06-14T00:00:00-04:00","2024-06-17T00:00:00-04:00","2024-06-18T00:00:00-04:00","2024-06-20T00:00:00-04:00","2024-06-21T00:00:00-04:00","2024-06-24T00:00:00-04:00","2024-06-25T00:00:00-04:00","2024-06-26T00:00:00-04:00","2024-06-27T00:00:00-04:00","2024-06-28T00:00:00-04:00","2024-07-01T00:00:00-04:00","2024-07-02T00:00:00-04:00","2024-07-03T00:00:00-04:00","2024-07-05T00:00:00-04:00","2024-07-08T00:00:00-04:00","2024-07-09T00:00:00-04:00","2024-07-10T00:00:00-04:00","2024-07-11T00:00:00-04:00","2024-07-12T00:00:00-04:00","2024-07-15T00:00:00-04:00","2024-07-16T00:00:00-04:00","2024-07-17T00:00:00-04:00","2024-07-18T00:00:00-04:00","2024-07-19T00:00:00-04:00","2024-07-22T00:00:00-04:00","2024-07-23T00:00:00-04:00","2024-07-24T00:00:00-04:00","2024-07-25T00:00:00-04:00","2024-07-26T00:00:00-04:00","2024-07-29T00:00:00-04:00","2024-07-30T00:00:00-04:00","2024-07-31T00:00:00-04:00","2024-08-01T00:00:00-04:00","2024-08-02T00:00:00-04:00","2024-08-05T00:00:00-04:00","2024-08-06T00:00:00-04:00","2024-08-07T00:00:00-04:00","2024-08-08T00:00:00-04:00","2024-08-09T00:00:00-04:00","2024-08-12T00:00:00-04:00","2024-08-13T00:00:00-04:00","2024-08-14T00:00:00-04:00","2024-08-15T00:00:00-04:00","2024-08-16T00:00:00-04:00","2024-08-19T00:00:00-04:00","2024-08-20T00:00:00-04:00","2024-08-21T00:00:00-04:00","2024-08-22T00:00:00-04:00","2024-08-23T00:00:00-04:00","2024-08-26T00:00:00-04:00","2024-08-27T00:00:00-04:00","2024-08-28T00:00:00-04:00","2024-08-29T00:00:00-04:00","2024-08-30T00:00:00-04:00","2024-09-03T00:00:00-04:00","2024-09-04T00:00:00-04:00","2024-09-05T00:00:00-04:00","2024-09-06T00:00:00-04:00","2024-09-09T00:00:00-04:00","2024-09-10T00:00:00-04:00","2024-09-11T00:00:00-04:00","2024-09-12T00:00:00-04:00","2024-09-13T00:00:00-04:00","2024-09-16T00:00:00-04:00","2024-09-17T00:00:00-04:00","2024-09-18T00:00:00-04:00","2024-09-19T00:00:00-04:00","2024-09-20T00:00:00-04:00","2024-09-23T00:00:00-04:00","2024-09-24T00:00:00-04:00","2024-09-25T00:00:00-04:00","2024-09-26T00:00:00-04:00","2024-09-27T00:00:00-04:00","2024-09-30T00:00:00-04:00","2024-10-01T00:00:00-04:00","2024-10-02T00:00:00-04:00","2024-10-03T00:00:00-04:00","2024-10-04T00:00:00-04:00","2024-10-07T00:00:00-04:00","2024-10-08T00:00:00-04:00","2024-10-09T00:00:00-04:00","2024-10-10T00:00:00-04:00","2024-10-11T00:00:00-04:00","2024-10-14T00:00:00-04:00","2024-10-15T00:00:00-04:00","2024-10-16T00:00:00-04:00","2024-10-17T00:00:00-04:00","2024-10-18T00:00:00-04:00","2024-10-21T00:00:00-04:00","2024-10-22T00:00:00-04:00","2024-10-23T00:00:00-04:00","2024-10-24T00:00:00-04:00","2024-10-25T00:00:00-04:00","2024-10-28T00:00:00-04:00","2024-10-29T00:00:00-04:00","2024-10-30T00:00:00-04:00","2024-10-31T00:00:00-04:00","2024-11-01T00:00:00-04:00","2024-11-04T00:00:00-05:00","2024-11-05T00:00:00-05:00","2024-11-06T00:00:00-05:00","2024-11-07T00:00:00-05:00","2024-11-08T00:00:00-05:00","2024-11-11T00:00:00-05:00","2024-11-12T00:00:00-05:00","2024-11-13T00:00:00-05:00","2024-11-14T00:00:00-05:00","2024-11-15T00:00:00-05:00","2024-11-18T00:00:00-05:00","2024-11-19T00:00:00-05:00","2024-11-20T00:00:00-05:00","2024-11-21T00:00:00-05:00","2024-11-22T00:00:00-05:00","2024-11-25T00:00:00-05:00","2024-11-26T00:00:00-05:00","2024-11-27T00:00:00 ...
# ============================================================
# ANALYZING ISSC
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing ISSC using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 40/100 - Average annual earnings growth: 11.4%
# N - New Products: 100/100 - Revenue growth: 35.6% (proxy for new products/services)
# S - Supply & Demand: 80/100 - Volume pattern score: 0.29 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 40/100 - Market cap: $0.3B, Volume change: 456.6%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 51.4/100
#
# 🎯 SIGNAL: HOLD
# Current Price: $15.55
# 20-day SMA: $14.34
# 50-day SMA: $12.22
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e1840c4c-f1bc-41de-bb29-34be91aa1ac2" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e1840c4c-f1bc-41de-bb29-34be91aa1ac2")) {                    Plotly.newPlot(                        "e1840c4c-f1bc-41de-bb29-34be91aa1ac2",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ============================================================
# ANALYZING MPWR
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing MPWR using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 100/100 - Average annual earnings growth: 132.2%
# N - New Products: 100/100 - Revenue growth: 21.2% (proxy for new products/services)
# S - Supply & Demand: 40/100 - Volume pattern score: -0.00 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 40/100 - Market cap: $34.5B, Volume change: -23.6%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 54.3/100
#
# 🎯 SIGNAL: HOLD
# Current Price: $719.98
# 20-day SMA: $733.62
# 50-day SMA: $708.62
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="de1f375a-0e8b-4390-a5e2-e9f6a4944458" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("de1f375a-0e8b-4390-a5e2-e9f6a4944458")) {                    Plotly.newPlot(                        "de1f375a-0e8b-4390-a5e2-e9f6a4944458",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ============================================================
# ANALYZING PLMR
# ============================================================
# [*********************100%***********************]  1 of 1 completed
# Analyzing PLMR using CANSLIM methodology...
# ==================================================
# [*********************100%***********************]  1 of 1 completed
# C - Current Earnings: 0/100 - No quarterly earnings data available
# A - Annual Earnings: 100/100 - Average annual earnings growth: 38.0%
# N - New Products: 100/100 - Revenue growth: 47.3% (proxy for new products/services)
# S - Supply & Demand: 80/100 - Volume pattern score: 0.15 (higher volume on up days is positive)
# L - Leader/Laggard: 50/100 - Error analyzing leader/laggard: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# I - Institutional: 80/100 - Market cap: $3.7B, Volume change: 80.9%
# M - Market Direction: 50/100 - Error analyzing market direction: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
# ==================================================
# Overall CANSLIM Score: 65.7/100
#
# 🎯 SIGNAL: STRONG SELL
# Current Price: $137.80
# 20-day SMA: $145.17
# 50-day SMA: $155.24
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a2af0e7f-3bcd-49a0-8ab6-1fe390572595" class="plotly-graph-div" style="height:1000px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a2af0e7f-3bcd-49a0-8ab6-1fe390572595")) {                    Plotly.newPlot(                        "a2af0e7f-3bcd-49a0-8ab6-1fe390572595",                        [{"name":"Close Price","x":["2023-07-24T00:00:00-04:00","2023-07-25T00:00:00-04:00","2023-07-26T00:00:00-04:00","2023-07-27T00:00:00-04:00","2023-07-28T00:00:00-04:00","2023-07-31T00:00:00-04:00","2023-08-01T00:00:00-04:00","2023-08-02T00:00:00-04:00","2023-08-03T00:00:00-04:00","2023-08-04T00:00:00-04:00","2023-08-07T00:00:00-04:00","2023-08-08T00:00:00-04:00","2023-08-09T00:00:00-04:00","2023-08-10T00:00:00-04:00","2023-08-11T00:00:00-04:00","2023-08-14T00:00:00-04:00","2023-08-15T00:00:00-04:00","2023-08-16T00:00:00-04:00","2023-08-17T00:00:00-04:00","2023-08-18T00:00:00-04:00","2023-08-21T00:00:00-04:00","2023-08-22T00:00:00-04:00","2023-08-23T00:00:00-04:00","2023-08-24T00:00:00-04:00","2023-08-25T00:00:00-04:00","2023-08-28T00:00:00-04:00","2023-08-29T00:00:00-04:00","2023-08-30T00:00:00-04:00","2023-08-31T00:00:00-04:00","2023-09-01T00:00:00-04:00","2023-09-05T00:00:00-04:00","2023-09-06T00:00:00-04:00","2023-09-07T00:00:00-04:00","2023-09-08T00:00:00-04:00","2023-09-11T00:00:00-04:00","2023-09-12T00:00:00-04:00","2023-09-13T00:00:00-04:00","2023-09-14T00:00:00-04:00","2023-09-15T00:00:00-04:00","2023-09-18T00:00:00-04:00","2023-09-19T00:00:00-04:00","2023-09-20T00:00:00-04:00","2023-09-21T00:00:00-04:00","2023-09-22T00:00:00-04:00","2023-09-25T00:00:00-04:00","2023-09-26T00:00:00-04:00","2023-09-27T00:00:00-04:00","2023-09-28T00:00:00-04:00","2023-09-29T00:00:00-04:00","2023-10-02T00:00:00-04:00","2023-10-03T00:00:00-04:00","2023-10-04T00:00:00-04:00","2023-10-05T00:00:00-04:00","2023-10-06T00:00:00-04:00","2023-10-09T00:00:00-04:00","2023-10-10T00:00:00-04:00","2023-10-11T00:00:00-04:00","2023-10-12T00:00:00-04:00","2023-10-13T00:00:00-04:00","2023-10-16T00:00:00-04:00","2023-10-17T00:00:00-04:00","2023-10-18T00:00:00-04:00","2023-10-19T00:00:00-04:00","2023-10-20T00:00:00-04:00","2023-10-23T00:00:00-04:00","2023-10-24T00:00:00-04:00","2023-10-25T00:00:00-04:00","2023-10-26T00:00:00-04:00","2023-10-27T00:00:00-04:00","2023-10-30T00:00:00-04:00","2023-10-31T00:00:00-04:00","2023-11-01T00:00:00-04:00","2023-11-02T00:00:00-04:00","2023-11-03T00:00:00-04:00","2023-11-06T00:00:00-05:00","2023-11-07T00:00:00-05:00","2023-11-08T00:00:00-05:00","2023-11-09T00:00:00-05:00","2023-11-10T00:00:00-05:00","2023-11-13T00:00:00-05:00","2023-11-14T00:00:00-05:00","2023-11-15T00:00:00-05:00","2023-11-16T00:00:00-05:00","2023-11-17T00:00:00-05:00","2023-11-20T00:00:00-05:00","2023-11-21T00:00:00-05:00","2023-11-22T00:00:00-05:00","2023-11-24T00:00:00-05:00","2023-11-27T00:00:00-05:00","2023-11-28T00:00:00-05:00","2023-11-29T00:00:00-05:00","2023-11-30T00:00:00-05:00","2023-12-01T00:00:00-05:00","2023-12-04T00:00:00-05:00","2023-12-05T00:00:00-05:00","2023-12-06T00:00:00-05:00","2023-12-07T00:00:00-05:00","2023-12-08T00:00:00-05:00","2023-12-11T00:00:00-05:00","2023-12-12T00:00:00-05:00","2023-12-13T00:00:00-05:00","2023-12-14T00:00:00-05:00","2023-12-15T00:00:00-05:00","2023-12-18T00:00:00-05:00","2023-12-19T00:00:00-05:00","2023-12-20T00:00:00-05:00","2023-12-21T00:00:00-05:00","2023-12-22T00:00:00-05:00","2023-12-26T00:00:00-05:00","2023-12-27T00:00:00-05:00","2023-12-28T00:00:00-05:00","2023-12-29T00:00:00-05:00","2024-01-02T00:00:00-05:00","2024-01-03T00:00:00-05:00","2024-01-04T00:00:00-05:00","2024-01-05T00:00:00-05:00","2024-01-08T00:00:00-05:00","2024-01-09T00:00:00-05:00","2024-01-10T00:00:00-05:00","2024-01-11T00:00:00-05:00","2024-01-12T00:00:00-05:00","2024-01-16T00:00:00 ...
# ================================================================================
# CANSLIM ANALYSIS SUMMARY
# ================================================================================
# Stock      Signal     Score
#  PLMR STRONG SELL 65.714286
#   OLO         BUY 62.857143
#  TOST         BUY 60.000000
#  NVDA         BUY 60.000000
#  NVAX        HOLD 57.142857
#  XERS        HOLD 54.285714
#  MPWR        HOLD 54.285714
#  ISSC        HOLD 51.428571
#   LIF        HOLD 51.428571
#  EVLV        HOLD 48.571429
# ================================================================================
# CUSTOM ANALYSIS INSTRUCTIONS
# ================================================================================
# To analyze your own stocks, use the following code:
#
# # Single stock analysis
# analyzer = CANSLIMAnalyzer('YOUR_SYMBOL', period='2y')
# signal, score = analyzer.generate_signals()
# analyzer.plot_analysis()
#
# # Multiple stocks analysis
# my_stocks = ['STOCK1', 'STOCK2', 'STOCK3']
# my_results = analyze_multiple_stocks(my_stocks, period='2y')
#
# Remember:
# - CANSLIM is a growth stock methodology
# - Scores above 70 indicate strong buy candidates
# - Scores below 40 suggest avoiding the stock
# - Always consider overall market conditions
# - This is for educational purposes - do your own research!
